# %% [markdown]
# # RiskPulse DeepML — 02. Data Validation & Outlier Handling
#
# **Objective**:
# - Remove duplicate records from the dataset.
# - Validate demographic features (`person_age`, `person_emp_length`).
# - Enforce positive financial bounds (`person_income`, `loan_amnt`).
# - Check interest rate sanity (`loan_int_rate`) and verify ratio consistency (`loan_percent_income`).
# - Export the cleaned dataset to `data/cleaned_credit_risk_dataset.csv` for feature engineering and model training.

# %% [markdown]
# ## 1. Environment Setup & Data Loading

# %% [markdown]
# ## 2. Duplicate Detection & Removal

# %% [markdown]
# ## 3. Demographic Sanity Checks (`person_age` & `person_emp_length`)

# %% [markdown]
# ## 4. Financial Bounds Checks (`person_income` & `loan_amnt`)

# %% [markdown]
# ## 5. Interest Rate & Ratio Consistency Checks

# %% [markdown]
# ## 6. Summary of Data Cleaning & Exporting Clean Dataset
